# %%
import librosa
import numpy as np
import os
import matplotlib.pyplot as plt
import soundfile as sf

# Definieren der Variablen
source_dir = "test_data/noise_2.wav"
source_dir_2 = "path_to_output_directory/knock_3_var1.wav"
y, sr = librosa.load(source_dir)
y_2, sr_2 = librosa.load(source_dir_2)

# Berechnen von MFCCs und Mel-Spektrogramm
mfcc = librosa.feature.mfcc(y=y, sr=sr)
mfcc_2 = librosa.feature.mfcc(y=y_2, sr=sr_2)
spectrogram = librosa.feature.melspectrogram(y=y, sr=sr)
spectrogram_2 = librosa.feature.melspectrogram(y=y_2, sr=sr_2)
print("Spectrogram:", spectrogram.shape)
print("Spectrogram_2:", spectrogram_2.shape)
print("MFCCs:", mfcc.shape)
print("MFCC_2s:", mfcc_2.shape)
print(len(y), len(y_2))


# Plot the spectrogram
plt.figure(figsize=(10, 4))
plt.imshow(spectrogram, cmap='hot', origin='lower', aspect='auto')
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogram')
plt.xlabel('Time')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()


# Plot the MFCC data
plt.figure(figsize=(10, 4))
plt.imshow(mfcc, cmap='hot', origin='lower', aspect='auto')
plt.colorbar(format='%+2.0f dB')
plt.title('MFCC')
plt.xlabel('Time')
plt.ylabel('MFCC Coefficients')
plt.tight_layout()
plt.show()

# Plot the MFCC data
plt.figure(figsize=(10, 4))
plt.imshow(mfcc_2, cmap='hot', origin='lower', aspect='auto')
plt.colorbar(format='%+2.0f dB')
plt.title('MFCC')
plt.xlabel('Time')
plt.ylabel('MFCC Coefficients')
plt.tight_layout()
plt.show()

overlapped_y = y + y_2
sf.write("output.wav", overlapped_y, sr)
# Out:
# Spectrogram: (128, 87)
# Spectrogram_2: (128, 87)
# MFCCs: (20, 87)
# MFCC_2s: (20, 87)
# 44100 44100

# %%
import pandas as pd

# Create a DataFrame with the MFCCs and Mel-Spectrogram data
data = {
    "mfcc": [mfcc],
    "mel": [mel]
}

# Add a column for the labels if needed
# data["label"] = labels

# Create a DataFrame
df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
df.to_csv("audio_data.csv", index=False)

# %%
# # Durchlaufen des Ordners und Vorverarbeiten der Audiodateien
# data = []
# labels = []
# for filename in os.listdir(source_dir):
#     filepath = os.path.join(source_dir, filename)
    
#     # Ignorieren von Verzeichnissen
#     if os.path.isdir(filepath):
#         continue
    
#     # Audio laden
#     y, sr = librosa.load(filepath)

#     # Berechnen von MFCCs und Mel-Spektrogramm
#     mfcc = librosa.feature.mfcc(y)
#     mel = librosa.feature.melspectrogram(y)

#     # Daten und Label speichern
#     data.append([mfcc, mel])
#     labels.append(1 if filename.startswith("knock") else 0)

# import pandas as pd

# # Pandas DataFrame erstellen
# df = pd.DataFrame(data, columns=["mfcc", "mel"])
# df["label"] = labels

# df.to_csv("audio_data.csv", index=False)
