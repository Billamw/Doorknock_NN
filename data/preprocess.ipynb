# %%
import librosa
import torch
import numpy as np
import os

# Definieren der Variablen
source_dirs = ["data/knocks", "data/knocks_with_noise", "data/noises"]

# Durchlaufen des Ordners und Vorverarbeiten der Audiodateien
data = []
labels = []
for source_dir in source_dirs:
    for filename in os.listdir(source_dir):
        filepath = os.path.join(source_dir, filename)
        
        # Ignorieren von Verzeichnissen
        if os.path.isdir(filepath):
            continue
        
        # Audio laden
        y, sr = librosa.load(filepath)

        # Berechnen von MFCCs
        mfcc = librosa.feature.mfcc(y=y, sr=sr)

        print(mfcc.shape, len(mfcc), len(mfcc[0]))

        # Hinzufügen einer Kanaldimension
        mfcc = np.expand_dims(mfcc, axis=0)
        print(mfcc.shape, len(mfcc), len(mfcc[0]))


        data.append(mfcc)
        labels.append(1 if filename.startswith("knock") else 0)


from torch.utils.data import Dataset

class AudioDataset(Dataset):
    def __init__(self, data, labels, transform=None):
        self.data = data
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        sample = self.data[idx]
        if self.transform:
            sample = self.transform(sample)
        return sample, self.labels[idx]
    
from torchvision import transforms

# Definieren der Transformation
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])
    
dataset = AudioDataset(data, labels, transform=transform)
# Speichern des Datasets
torch.save(dataset, 'dataset.pth')
# Out:
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20
# (20, 87) 20 87
# (1, 20, 87) 1 20

# %%
from torchvision import transforms

dataset = torch.load('dataset.pth')
print(type(dataset), len(dataset))
print(type(dataset.__getitem__(0)))
print(dataset.__getitem__(0))
# Out:
# <class '__main__.AudioDataset'> 274
# <class 'tuple'>
# (tensor([[[-1.2745e+03,  2.3464e+02, -2.7337e+01,  ...,  4.8698e+00,
#           -1.0860e+00,  1.0392e+01]],
#
#         [[-1.2037e+03,  2.3812e+02, -2.9034e+01,  ...,  1.4742e+00,
#            2.0559e+00,  8.2397e+00]],
#
#         [[-1.1983e+03,  2.4000e+02, -3.1538e+01,  ..., -5.7936e-01,
#           -2.9374e+00,  6.7674e+00]],
#
#         ...,
#
#         [[-1.1934e+03,  2.5568e+02, -1.3737e+01,  ...,  6.0407e-01,
#           -9.4601e+00,  9.7316e+00]],
#
#         [[-1.2061e+03,  2.4852e+02, -7.8982e+00,  ...,  4.9105e+00,
#           -9.9413e+00,  2.6640e+00]],
#
#         [[-1.2610e+03,  2.4565e+02, -8.5355e+00,  ..., -9.6243e-01,
#           -1.0896e+01,  8.8208e+00]]]), 1)

# %% [markdown]
# # Version for V7

# %%
import os
import shutil
from glob import glob
import random

# Seed for reproducibility
random.seed(42)

# Source directories
source_dirs = ["data/knocks", "data/knocks_with_noise", "data/noises", "data/new_knocks"]

# Destination directories
dest_dirs = {
    "train": "data/trainv2",
    "test": "data/testv2",
    "validation": "data/validationv2"
}

# Collect all sound files
sound_files = []
for source_dir in source_dirs:
    sound_files.extend(glob(os.path.join(source_dir, "*.wav")))

# Shuffle the sound files
random.shuffle(sound_files)

# Split the data
num_test = 20
num_remaining = len(sound_files) - num_test
num_train = int(num_remaining * 0.8)
num_validation = num_remaining - num_train

# Ensure destination directories exist
for dir_path in dest_dirs.values():
    os.makedirs(dir_path, exist_ok=True)

# Function to copy files to destination
def copy_files(files, destination):
    for file in files:
        shutil.copy(file, destination)

# Copy files to their respective directories
copy_files(sound_files[:num_test], dest_dirs["test"])
copy_files(sound_files[num_test:num_test + num_train], dest_dirs["train"])
copy_files(sound_files[num_test + num_train:], dest_dirs["validation"])

print(f"Files distributed: {num_test} test, {num_train} train, {num_validation} validation.")
# Out:
# Files distributed: 20 test, 1699 train, 425 validation.

# %%
import os

def rename_files_in_directory(directory, start_index=1):
    """
    Renames files in the specified directory that do not contain an underscore in their name.
    Files are renamed to 'knock_new_x', where x is a sequential number starting from start_index.
    Returns the next start index after renaming files in this directory.
    """
    # Get a list of file names in the directory
    files = os.listdir(directory)
    current_index = start_index
    
    for file in files:
        # Check if the file name does not contain an underscore
        if '_' not in file:
            # Define the new file name
            new_file_name = f'knock_new_{current_index}.wav'  # Assuming the files are .wav, change the extension if necessary
            # Rename the file
            os.rename(os.path.join(directory, file), os.path.join(directory, new_file_name))
            # Increment the index for the next file
            current_index += 1
            
    # Return the next start index
    return current_index

# Directories to process
directories = ['data/trainv2', 'data/testv2', 'data/validationv2']

# Start index for renaming
start_index = 1

# Iterate through each directory and rename files
for directory in directories:
    start_index = rename_files_in_directory(directory, start_index)

print("Finished renaming files.")
# Out:
# Finished renaming files.

# %% [markdown]
# ## Remove all augmented data

# %%
import os

# Pfad zum Hauptverzeichnis, in dem die Suche beginnen soll
root_dir = './'

# Durchlaufen aller Verzeichnisse, Unterordner und Dateien im root_dir
for dirpath, dirnames, filenames in os.walk(root_dir):
    for filename in filenames:
        # Überprüfen, ob die Datei die Kriterien erfüllt: WAV-Format und 'var' im Namen
        if filename.endswith('.wav') and 'var' in filename:
            # Vollständigen Pfad zur Datei generieren
            file_path = os.path.join(dirpath, filename)
            # Datei löschen
            os.remove(file_path)
            print(f"Gelöscht: {file_path}")
# Out:
# Gelöscht: ./test\knock_with_noise_1_var8.wav
# Gelöscht: ./test\noise_14_var3.wav
# Gelöscht: ./test\noise_24_var4.wav
# Gelöscht: ./test\noise_2_var6.wav
# Gelöscht: ./test\noise_30_var0.wav
# Gelöscht: ./test\noise_34_var0.wav
# Gelöscht: ./test\noise_58_var6.wav
# Gelöscht: ./test\noise_63_var3.wav
# Gelöscht: ./test\noise_76_var3.wav
# Gelöscht: ./test\noise_82_var2.wav
# Gelöscht: ./test\noise_92_var4.wav
# Gelöscht: ./test\noise_93_var8.wav
# Gelöscht: ./test\noise_99_var1.wav
# Gelöscht: ./train\knock_10_var0.wav
# Gelöscht: ./train\knock_10_var1.wav
# Gelöscht: ./train\knock_10_var3.wav
# Gelöscht: ./train\knock_10_var5.wav
# Gelöscht: ./train\knock_10_var6.wav
# Gelöscht: ./train\knock_10_var7.wav
# Gelöscht: ./train\knock_10_var8.wav
# Gelöscht: ./train\knock_10_var9.wav
# Gelöscht: ./train\knock_11_var0.wav
# Gelöscht: ./train\knock_11_var2.wav
# Gelöscht: ./train\knock_11_var4.wav
# Gelöscht: ./train\knock_11_var5.wav
# Gelöscht: ./train\knock_11_var7.wav
# Gelöscht: ./train\knock_11_var8.wav
# Gelöscht: ./train\knock_11_var9.wav
# Gelöscht: ./train\knock_1_var1.wav
# Gelöscht: ./train\knock_1_var2.wav
# Gelöscht: ./train\knock_1_var4.wav
# Gelöscht: ./train\knock_1_var5.wav
# Gelöscht: ./train\knock_1_var6.wav
# Gelöscht: ./train\knock_1_var8.wav
# Gelöscht: ./train\knock_1_var9.wav
# Gelöscht: ./train\knock_2_var0.wav
# Gelöscht: ./train\knock_2_var1.wav
# Gelöscht: ./train\knock_2_var2.wav
# Gelöscht: ./train\knock_2_var3.wav
# Gelöscht: ./train\knock_2_var4.wav
# Gelöscht: ./train\knock_2_var6.wav
# Gelöscht: ./train\knock_2_var7.wav
# Gelöscht: ./train\knock_2_var8.wav
# Gelöscht: ./train\knock_3_var0.wav
# Gelöscht: ./train\knock_3_var1.wav
# Gelöscht: ./train\knock_3_var2.wav
# Gelöscht: ./train\knock_3_var3.wav
# Gelöscht: ./train\knock_3_var4.wav
# Gelöscht: ./train\knock_3_var5.wav
# Gelöscht: ./train\knock_3_var6.wav
# Gelöscht: ./train\knock_3_var7.wav
# Gelöscht: ./train\knock_3_var8.wav
# Gelöscht: ./train\knock_3_var9.wav
# Gelöscht: ./train\knock_4_var0.wav
# Gelöscht: ./train\knock_4_var1.wav
# Gelöscht: ./train\knock_4_var2.wav
# Gelöscht: ./train\knock_4_var3.wav
# Gelöscht: ./train\knock_4_var4.wav
# Gelöscht: ./train\knock_4_var5.wav
# Gelöscht: ./train\knock_4_var6.wav
# Gelöscht: ./train\knock_4_var7.wav
# Gelöscht: ./train\knock_4_var9.wav
# Gelöscht: ./train\knock_5_var0.wav
# Gelöscht: ./train\knock_5_var1.wav
# Gelöscht: ./train\knock_5_var2.wav
# Gelöscht: ./train\knock_5_var3.wav
# Gelöscht: ./train\knock_5_var4.wav
# Gelöscht: ./train\knock_5_var5.wav
# Gelöscht: ./train\knock_5_var6.wav
# Gelöscht: ./train\knock_5_var7.wav
# Gelöscht: ./train\knock_5_var8.wav
# Gelöscht: ./train\knock_5_var9.wav
# Gelöscht: ./train\knock_6_var0.wav
# Gelöscht: ./train\knock_6_var1.wav
# Gelöscht: ./train\knock_6_var2.wav
# Gelöscht: ./train\knock_6_var4.wav
# Gelöscht: ./train\knock_6_var5.wav
# Gelöscht: ./train\knock_6_var6.wav
# Gelöscht: ./train\knock_6_var7.wav
# Gelöscht: ./train\knock_6_var8.wav
# Gelöscht: ./train\knock_6_var9.wav
# Gelöscht: ./train\knock_7_var0.wav
# Gelöscht: ./train\knock_7_var1.wav
# Gelöscht: ./train\knock_7_var2.wav
# Gelöscht: ./train\knock_7_var3.wav
# Gelöscht: ./train\knock_7_var4.wav
# Gelöscht: ./train\knock_7_var5.wav
# Gelöscht: ./train\knock_7_var6.wav
# Gelöscht: ./train\knock_7_var7.wav
# Gelöscht: ./train\knock_7_var8.wav
# Gelöscht: ./train\knock_7_var9.wav
# Gelöscht: ./train\knock_8_var0.wav
# Gelöscht: ./train\knock_8_var1.wav
# Gelöscht: ./train\knock_8_var4.wav
# Gelöscht: ./train\knock_8_var5.wav
# Gelöscht: ./train\knock_8_var6.wav
# Gelöscht: ./train\knock_8_var7.wav
# Gelöscht: ./train\knock_8_var9.wav
# Gelöscht: ./train\knock_9_var0.wav
# Gelöscht: ./train\knock_9_var1.wav
# Gelöscht: ./train\knock_9_var2.wav
# Gelöscht: ./train\knock_9_var3.wav
# Gelöscht: ./train\knock_9_var4.wav
# Gelöscht: ./train\knock_with_noise_10_var0.wav
# Gelöscht: ./train\knock_with_noise_10_var1.wav
# Gelöscht: ./train\knock_with_noise_10_var2.wav
# Gelöscht: ./train\knock_with_noise_10_var3.wav
# Gelöscht: ./train\knock_with_noise_10_var8.wav
# Gelöscht: ./train\knock_with_noise_10_var9.wav
# Gelöscht: ./train\knock_with_noise_11_var1.wav
# Gelöscht: ./train\knock_with_noise_11_var2.wav
# Gelöscht: ./train\knock_with_noise_11_var4.wav
# Gelöscht: ./train\knock_with_noise_11_var6.wav
# Gelöscht: ./train\knock_with_noise_11_var7.wav
# Gelöscht: ./train\knock_with_noise_11_var8.wav
# Gelöscht: ./train\knock_with_noise_12_var0.wav
# Gelöscht: ./train\knock_with_noise_12_var1.wav
# Gelöscht: ./train\knock_with_noise_12_var2.wav
# Gelöscht: ./train\knock_with_noise_12_var3.wav
# Gelöscht: ./train\knock_with_noise_12_var4.wav
# Gelöscht: ./train\knock_with_noise_12_var6.wav
# Gelöscht: ./train\knock_with_noise_12_var7.wav
# Gelöscht: ./train\knock_with_noise_12_var9.wav
# Gelöscht: ./train\knock_with_noise_13_var1.wav
# Gelöscht: ./train\knock_with_noise_13_var2.wav
# Gelöscht: ./train\knock_with_noise_13_var3.wav
# Gelöscht: ./train\knock_with_noise_13_var4.wav
# Gelöscht: ./train\knock_with_noise_13_var5.wav
# Gelöscht: ./train\knock_with_noise_13_var6.wav
# Gelöscht: ./train\knock_with_noise_13_var7.wav
# Gelöscht: ./train\knock_with_noise_13_var9.wav
# Gelöscht: ./train\knock_with_noise_14_var0.wav
# Gelöscht: ./train\knock_with_noise_14_var1.wav
# Gelöscht: ./train\knock_with_noise_14_var2.wav
# Gelöscht: ./train\knock_with_noise_14_var3.wav
# Gelöscht: ./train\knock_with_noise_14_var4.wav
# Gelöscht: ./train\knock_with_noise_14_var5.wav
# Gelöscht: ./train\knock_with_noise_14_var6.wav
# Gelöscht: ./train\knock_with_noise_14_var7.wav
# Gelöscht: ./train\knock_with_noise_14_var8.wav
# Gelöscht: ./train\knock_with_noise_15_var0.wav
# Gelöscht: ./train\knock_with_noise_15_var1.wav
# Gelöscht: ./train\knock_with_noise_15_var5.wav
# Gelöscht: ./train\knock_with_noise_15_var6.wav
# Gelöscht: ./train\knock_with_noise_15_var7.wav
# Gelöscht: ./train\knock_with_noise_15_var8.wav
# Gelöscht: ./train\knock_with_noise_17_var0.wav
# Gelöscht: ./train\knock_with_noise_17_var1.wav
# Gelöscht: ./train\knock_with_noise_17_var2.wav
# Gelöscht: ./train\knock_with_noise_17_var3.wav
# Gelöscht: ./train\knock_with_noise_17_var4.wav
# Gelöscht: ./train\knock_with_noise_17_var5.wav
# Gelöscht: ./train\knock_with_noise_17_var7.wav
# Gelöscht: ./train\knock_with_noise_17_var8.wav
# Gelöscht: ./train\knock_with_noise_17_var9.wav
# Gelöscht: ./train\knock_with_noise_18_var0.wav
# Gelöscht: ./train\knock_with_noise_18_var2.wav
# Gelöscht: ./train\knock_with_noise_18_var3.wav
# Gelöscht: ./train\knock_with_noise_18_var4.wav
# Gelöscht: ./train\knock_with_noise_18_var5.wav
# Gelöscht: ./train\knock_with_noise_18_var8.wav
# Gelöscht: ./train\knock_with_noise_18_var9.wav
# Gelöscht: ./train\knock_with_noise_19_var0.wav
# Gelöscht: ./train\knock_with_noise_19_var2.wav
# Gelöscht: ./train\knock_with_noise_19_var3.wav
# Gelöscht: ./train\knock_with_noise_19_var4.wav
# Gelöscht: ./train\knock_with_noise_19_var5.wav
# Gelöscht: ./train\knock_with_noise_19_var6.wav
# Gelöscht: ./train\knock_with_noise_19_var7.wav
# Gelöscht: ./train\knock_with_noise_19_var8.wav
# Gelöscht: ./train\knock_with_noise_19_var9.wav
# Gelöscht: ./train\knock_with_noise_1_var0.wav
# Gelöscht: ./train\knock_with_noise_1_var1.wav
# Gelöscht: ./train\knock_with_noise_1_var3.wav
# Gelöscht: ./train\knock_with_noise_1_var5.wav
# Gelöscht: ./train\knock_with_noise_1_var6.wav
# Gelöscht: ./train\knock_with_noise_1_var7.wav
# Gelöscht: ./train\knock_with_noise_1_var9.wav
# Gelöscht: ./train\knock_with_noise_21_var0.wav
# Gelöscht: ./train\knock_with_noise_21_var1.wav
# Gelöscht: ./train\knock_with_noise_21_var3.wav
# Gelöscht: ./train\knock_with_noise_21_var6.wav
# Gelöscht: ./train\knock_with_noise_21_var7.wav
# Gelöscht: ./train\knock_with_noise_21_var8.wav
# Gelöscht: ./train\knock_with_noise_21_var9.wav
# Gelöscht: ./train\knock_with_noise_22_var0.wav
# Gelöscht: ./train\knock_with_noise_22_var1.wav
# Gelöscht: ./train\knock_with_noise_22_var2.wav
# Gelöscht: ./train\knock_with_noise_22_var3.wav
# Gelöscht: ./train\knock_with_noise_22_var4.wav
# Gelöscht: ./train\knock_with_noise_22_var5.wav
# Gelöscht: ./train\knock_with_noise_22_var6.wav
# Gelöscht: ./train\knock_with_noise_22_var8.wav
# Gelöscht: ./train\knock_with_noise_22_var9.wav
# Gelöscht: ./train\knock_with_noise_23_var0.wav
# Gelöscht: ./train\knock_with_noise_23_var1.wav
# Gelöscht: ./train\knock_with_noise_23_var2.wav
# Gelöscht: ./train\knock_with_noise_23_var3.wav
# Gelöscht: ./train\knock_with_noise_23_var5.wav
# Gelöscht: ./train\knock_with_noise_23_var6.wav
# Gelöscht: ./train\knock_with_noise_23_var7.wav
# Gelöscht: ./train\knock_with_noise_23_var8.wav
# Gelöscht: ./train\knock_with_noise_23_var9.wav
# Gelöscht: ./train\knock_with_noise_25_var0.wav
# Gelöscht: ./train\knock_with_noise_25_var1.wav
# Gelöscht: ./train\knock_with_noise_25_var2.wav
# Gelöscht: ./train\knock_with_noise_25_var4.wav
# Gelöscht: ./train\knock_with_noise_25_var5.wav
# Gelöscht: ./train\knock_with_noise_25_var6.wav
# Gelöscht: ./train\knock_with_noise_25_var8.wav
# Gelöscht: ./train\knock_with_noise_25_var9.wav
# Gelöscht: ./train\knock_with_noise_26_var0.wav
# Gelöscht: ./train\knock_with_noise_26_var3.wav
# Gelöscht: ./train\knock_with_noise_26_var4.wav
# Gelöscht: ./train\knock_with_noise_26_var7.wav
# Gelöscht: ./train\knock_with_noise_26_var8.wav
# Gelöscht: ./train\knock_with_noise_27_var0.wav
# Gelöscht: ./train\knock_with_noise_27_var1.wav
# Gelöscht: ./train\knock_with_noise_27_var2.wav
# Gelöscht: ./train\knock_with_noise_27_var3.wav
# Gelöscht: ./train\knock_with_noise_27_var4.wav
# Gelöscht: ./train\knock_with_noise_27_var7.wav
# Gelöscht: ./train\knock_with_noise_27_var9.wav
# Gelöscht: ./train\knock_with_noise_2_var0.wav
# Gelöscht: ./train\knock_with_noise_2_var2.wav
# Gelöscht: ./train\knock_with_noise_2_var3.wav
# Gelöscht: ./train\knock_with_noise_2_var4.wav
# Gelöscht: ./train\knock_with_noise_2_var5.wav
# Gelöscht: ./train\knock_with_noise_2_var6.wav
# Gelöscht: ./train\knock_with_noise_2_var7.wav
# Gelöscht: ./train\knock_with_noise_2_var9.wav
# Gelöscht: ./train\knock_with_noise_30_var0.wav
# Gelöscht: ./train\knock_with_noise_30_var1.wav
# Gelöscht: ./train\knock_with_noise_30_var2.wav
# Gelöscht: ./train\knock_with_noise_30_var5.wav
# Gelöscht: ./train\knock_with_noise_30_var6.wav
# Gelöscht: ./train\knock_with_noise_30_var8.wav
# Gelöscht: ./train\knock_with_noise_30_var9.wav
# Gelöscht: ./train\knock_with_noise_31_var0.wav
# Gelöscht: ./train\knock_with_noise_31_var3.wav
# Gelöscht: ./train\knock_with_noise_31_var4.wav
# Gelöscht: ./train\knock_with_noise_31_var6.wav
# Gelöscht: ./train\knock_with_noise_31_var7.wav
# Gelöscht: ./train\knock_with_noise_31_var8.wav
# Gelöscht: ./train\knock_with_noise_32_var0.wav
# Gelöscht: ./train\knock_with_noise_32_var1.wav
# Gelöscht: ./train\knock_with_noise_32_var2.wav
# Gelöscht: ./train\knock_with_noise_32_var3.wav
# Gelöscht: ./train\knock_with_noise_32_var4.wav
# Gelöscht: ./train\knock_with_noise_32_var5.wav
# Gelöscht: ./train\knock_with_noise_32_var6.wav
# Gelöscht: ./train\knock_with_noise_32_var7.wav
# Gelöscht: ./train\knock_with_noise_32_var8.wav
# Gelöscht: ./train\knock_with_noise_33_var0.wav
# Gelöscht: ./train\knock_with_noise_33_var1.wav
# Gelöscht: ./train\knock_with_noise_33_var3.wav
# Gelöscht: ./train\knock_with_noise_33_var5.wav
# Gelöscht: ./train\knock_with_noise_33_var6.wav
# Gelöscht: ./train\knock_with_noise_33_var7.wav
# Gelöscht: ./train\knock_with_noise_33_var8.wav
# Gelöscht: ./train\knock_with_noise_34_var0.wav
# Gelöscht: ./train\knock_with_noise_34_var1.wav
# Gelöscht: ./train\knock_with_noise_34_var2.wav
# Gelöscht: ./train\knock_with_noise_34_var3.wav
# Gelöscht: ./train\knock_with_noise_34_var4.wav
# Gelöscht: ./train\knock_with_noise_34_var5.wav
# Gelöscht: ./train\knock_with_noise_34_var6.wav
# Gelöscht: ./train\knock_with_noise_34_var7.wav
# Gelöscht: ./train\knock_with_noise_34_var8.wav
# Gelöscht: ./train\knock_with_noise_34_var9.wav
# Gelöscht: ./train\knock_with_noise_35_var0.wav
# Gelöscht: ./train\knock_with_noise_35_var1.wav
# Gelöscht: ./train\knock_with_noise_35_var3.wav
# Gelöscht: ./train\knock_with_noise_35_var4.wav
# Gelöscht: ./train\knock_with_noise_35_var8.wav
# Gelöscht: ./train\knock_with_noise_35_var9.wav
# Gelöscht: ./train\knock_with_noise_36_var0.wav
# Gelöscht: ./train\knock_with_noise_36_var1.wav
# Gelöscht: ./train\knock_with_noise_36_var2.wav
# Gelöscht: ./train\knock_with_noise_36_var4.wav
# Gelöscht: ./train\knock_with_noise_36_var5.wav
# Gelöscht: ./train\knock_with_noise_36_var6.wav
# Gelöscht: ./train\knock_with_noise_36_var8.wav
# Gelöscht: ./train\knock_with_noise_37_var0.wav
# Gelöscht: ./train\knock_with_noise_37_var1.wav
# Gelöscht: ./train\knock_with_noise_37_var2.wav
# Gelöscht: ./train\knock_with_noise_37_var4.wav
# Gelöscht: ./train\knock_with_noise_37_var5.wav
# Gelöscht: ./train\knock_with_noise_37_var6.wav
# Gelöscht: ./train\knock_with_noise_37_var8.wav
# Gelöscht: ./train\knock_with_noise_37_var9.wav
# Gelöscht: ./train\knock_with_noise_38_var0.wav
# Gelöscht: ./train\knock_with_noise_38_var1.wav
# Gelöscht: ./train\knock_with_noise_38_var2.wav
# Gelöscht: ./train\knock_with_noise_38_var3.wav
# Gelöscht: ./train\knock_with_noise_38_var5.wav
# Gelöscht: ./train\knock_with_noise_38_var6.wav
# Gelöscht: ./train\knock_with_noise_38_var8.wav
# Gelöscht: ./train\knock_with_noise_38_var9.wav
# Gelöscht: ./train\knock_with_noise_39_var0.wav
# Gelöscht: ./train\knock_with_noise_39_var1.wav
# Gelöscht: ./train\knock_with_noise_39_var2.wav
# Gelöscht: ./train\knock_with_noise_39_var3.wav
# Gelöscht: ./train\knock_with_noise_39_var4.wav
# Gelöscht: ./train\knock_with_noise_39_var5.wav
# Gelöscht: ./train\knock_with_noise_39_var7.wav
# Gelöscht: ./train\knock_with_noise_39_var8.wav
# Gelöscht: ./train\knock_with_noise_3_var0.wav
# Gelöscht: ./train\knock_with_noise_3_var1.wav
# Gelöscht: ./train\knock_with_noise_3_var4.wav
# Gelöscht: ./train\knock_with_noise_3_var6.wav
# Gelöscht: ./train\knock_with_noise_3_var7.wav
# Gelöscht: ./train\knock_with_noise_3_var9.wav
# Gelöscht: ./train\knock_with_noise_40_var1.wav
# Gelöscht: ./train\knock_with_noise_40_var2.wav
# Gelöscht: ./train\knock_with_noise_40_var4.wav
# Gelöscht: ./train\knock_with_noise_40_var5.wav
# Gelöscht: ./train\knock_with_noise_40_var6.wav
# Gelöscht: ./train\knock_with_noise_40_var8.wav
# Gelöscht: ./train\knock_with_noise_40_var9.wav
# Gelöscht: ./train\knock_with_noise_41_var0.wav
# Gelöscht: ./train\knock_with_noise_41_var2.wav
# Gelöscht: ./train\knock_with_noise_41_var4.wav
# Gelöscht: ./train\knock_with_noise_41_var5.wav
# Gelöscht: ./train\knock_with_noise_41_var7.wav
# Gelöscht: ./train\knock_with_noise_41_var8.wav
# Gelöscht: ./train\knock_with_noise_41_var9.wav
# Gelöscht: ./train\knock_with_noise_42_var0.wav
# Gelöscht: ./train\knock_with_noise_42_var1.wav
# Gelöscht: ./train\knock_with_noise_42_var2.wav
# Gelöscht: ./train\knock_with_noise_42_var3.wav
# Gelöscht: ./train\knock_with_noise_42_var4.wav
# Gelöscht: ./train\knock_with_noise_42_var5.wav
# Gelöscht: ./train\knock_with_noise_42_var6.wav
# Gelöscht: ./train\knock_with_noise_42_var7.wav
# Gelöscht: ./train\knock_with_noise_42_var8.wav
# Gelöscht: ./train\knock_with_noise_42_var9.wav
# Gelöscht: ./train\knock_with_noise_43_var0.wav
# Gelöscht: ./train\knock_with_noise_43_var1.wav
# Gelöscht: ./train\knock_with_noise_43_var2.wav
# Gelöscht: ./train\knock_with_noise_43_var3.wav
# Gelöscht: ./train\knock_with_noise_43_var5.wav
# Gelöscht: ./train\knock_with_noise_43_var6.wav
# Gelöscht: ./train\knock_with_noise_43_var7.wav
# Gelöscht: ./train\knock_with_noise_43_var8.wav
# Gelöscht: ./train\knock_with_noise_44_var0.wav
# Gelöscht: ./train\knock_with_noise_44_var3.wav
# Gelöscht: ./train\knock_with_noise_44_var4.wav
# Gelöscht: ./train\knock_with_noise_44_var6.wav
# Gelöscht: ./train\knock_with_noise_44_var7.wav
# Gelöscht: ./train\knock_with_noise_44_var8.wav
# Gelöscht: ./train\knock_with_noise_44_var9.wav
# Gelöscht: ./train\knock_with_noise_45_var0.wav
# Gelöscht: ./train\knock_with_noise_45_var1.wav
# Gelöscht: ./train\knock_with_noise_45_var2.wav
# Gelöscht: ./train\knock_with_noise_45_var3.wav
# Gelöscht: ./train\knock_with_noise_45_var4.wav
# Gelöscht: ./train\knock_with_noise_45_var5.wav
# Gelöscht: ./train\knock_with_noise_45_var6.wav
# Gelöscht: ./train\knock_with_noise_45_var7.wav
# Gelöscht: ./train\knock_with_noise_45_var8.wav
# Gelöscht: ./train\knock_with_noise_45_var9.wav
# Gelöscht: ./train\knock_with_noise_46_var0.wav
# Gelöscht: ./train\knock_with_noise_46_var1.wav
# Gelöscht: ./train\knock_with_noise_46_var2.wav
# Gelöscht: ./train\knock_with_noise_46_var4.wav
# Gelöscht: ./train\knock_with_noise_46_var5.wav
# Gelöscht: ./train\knock_with_noise_46_var6.wav
# Gelöscht: ./train\knock_with_noise_46_var9.wav
# Gelöscht: ./train\knock_with_noise_47_var0.wav
# Gelöscht: ./train\knock_with_noise_47_var1.wav
# Gelöscht: ./train\knock_with_noise_47_var2.wav
# Gelöscht: ./train\knock_with_noise_47_var3.wav
# Gelöscht: ./train\knock_with_noise_47_var4.wav
# Gelöscht: ./train\knock_with_noise_47_var5.wav
# Gelöscht: ./train\knock_with_noise_47_var6.wav
# Gelöscht: ./train\knock_with_noise_47_var7.wav
# Gelöscht: ./train\knock_with_noise_47_var8.wav
# Gelöscht: ./train\knock_with_noise_49_var0.wav
# Gelöscht: ./train\knock_with_noise_49_var1.wav
# Gelöscht: ./train\knock_with_noise_49_var2.wav
# Gelöscht: ./train\knock_with_noise_49_var3.wav
# Gelöscht: ./train\knock_with_noise_49_var4.wav
# Gelöscht: ./train\knock_with_noise_49_var6.wav
# Gelöscht: ./train\knock_with_noise_49_var7.wav
# Gelöscht: ./train\knock_with_noise_49_var8.wav
# Gelöscht: ./train\knock_with_noise_49_var9.wav
# Gelöscht: ./train\knock_with_noise_4_var0.wav
# Gelöscht: ./train\knock_with_noise_4_var2.wav
# Gelöscht: ./train\knock_with_noise_4_var3.wav
# Gelöscht: ./train\knock_with_noise_4_var4.wav
# Gelöscht: ./train\knock_with_noise_4_var6.wav
# Gelöscht: ./train\knock_with_noise_4_var7.wav
# Gelöscht: ./train\knock_with_noise_4_var9.wav
# Gelöscht: ./train\knock_with_noise_5_var0.wav
# Gelöscht: ./train\knock_with_noise_5_var1.wav
# Gelöscht: ./train\knock_with_noise_5_var3.wav
# Gelöscht: ./train\knock_with_noise_5_var4.wav
# Gelöscht: ./train\knock_with_noise_5_var5.wav
# Gelöscht: ./train\knock_with_noise_5_var6.wav
# Gelöscht: ./train\knock_with_noise_5_var7.wav
# Gelöscht: ./train\knock_with_noise_5_var8.wav
# Gelöscht: ./train\knock_with_noise_6_var0.wav
# Gelöscht: ./train\knock_with_noise_6_var2.wav
# Gelöscht: ./train\knock_with_noise_6_var3.wav
# Gelöscht: ./train\knock_with_noise_6_var4.wav
# Gelöscht: ./train\knock_with_noise_6_var5.wav
# Gelöscht: ./train\knock_with_noise_6_var6.wav
# Gelöscht: ./train\knock_with_noise_6_var7.wav
# Gelöscht: ./train\knock_with_noise_6_var9.wav
# Gelöscht: ./train\knock_with_noise_7_var0.wav
# Gelöscht: ./train\knock_with_noise_7_var1.wav
# Gelöscht: ./train\knock_with_noise_7_var2.wav
# Gelöscht: ./train\knock_with_noise_7_var5.wav
# Gelöscht: ./train\knock_with_noise_7_var6.wav
# Gelöscht: ./train\knock_with_noise_7_var7.wav
# Gelöscht: ./train\knock_with_noise_7_var9.wav
# Gelöscht: ./train\knock_with_noise_8_var0.wav
# Gelöscht: ./train\knock_with_noise_8_var1.wav
# Gelöscht: ./train\knock_with_noise_8_var2.wav
# Gelöscht: ./train\knock_with_noise_8_var4.wav
# Gelöscht: ./train\knock_with_noise_8_var5.wav
# Gelöscht: ./train\knock_with_noise_8_var6.wav
# Gelöscht: ./train\knock_with_noise_8_var7.wav
# Gelöscht: ./train\knock_with_noise_8_var8.wav
# Gelöscht: ./train\knock_with_noise_8_var9.wav
# Gelöscht: ./train\noise_100_var0.wav
# Gelöscht: ./train\noise_100_var1.wav
# Gelöscht: ./train\noise_100_var3.wav
# Gelöscht: ./train\noise_100_var4.wav
# Gelöscht: ./train\noise_100_var5.wav
# Gelöscht: ./train\noise_100_var6.wav
# Gelöscht: ./train\noise_100_var7.wav
# Gelöscht: ./train\noise_100_var8.wav
# Gelöscht: ./train\noise_100_var9.wav
# Gelöscht: ./train\noise_10_var0.wav
# Gelöscht: ./train\noise_10_var1.wav
# Gelöscht: ./train\noise_10_var2.wav
# Gelöscht: ./train\noise_10_var3.wav
# Gelöscht: ./train\noise_10_var4.wav
# Gelöscht: ./train\noise_10_var5.wav
# Gelöscht: ./train\noise_10_var6.wav
# Gelöscht: ./train\noise_10_var7.wav
# Gelöscht: ./train\noise_10_var9.wav
# Gelöscht: ./train\noise_11_var0.wav
# Gelöscht: ./train\noise_11_var2.wav
# Gelöscht: ./train\noise_11_var3.wav
# Gelöscht: ./train\noise_11_var4.wav
# Gelöscht: ./train\noise_11_var6.wav
# Gelöscht: ./train\noise_11_var7.wav
# Gelöscht: ./train\noise_11_var8.wav
# Gelöscht: ./train\noise_11_var9.wav
# Gelöscht: ./train\noise_12_var0.wav
# Gelöscht: ./train\noise_12_var1.wav
# Gelöscht: ./train\noise_12_var2.wav
# Gelöscht: ./train\noise_12_var3.wav
# Gelöscht: ./train\noise_12_var4.wav
# Gelöscht: ./train\noise_12_var5.wav
# Gelöscht: ./train\noise_12_var6.wav
# Gelöscht: ./train\noise_12_var7.wav
# Gelöscht: ./train\noise_12_var9.wav
# Gelöscht: ./train\noise_13_var0.wav
# Gelöscht: ./train\noise_13_var1.wav
# Gelöscht: ./train\noise_13_var2.wav
# Gelöscht: ./train\noise_13_var3.wav
# Gelöscht: ./train\noise_13_var4.wav
# Gelöscht: ./train\noise_13_var5.wav
# Gelöscht: ./train\noise_13_var6.wav
# Gelöscht: ./train\noise_13_var7.wav
# Gelöscht: ./train\noise_13_var9.wav
# Gelöscht: ./train\noise_14_var0.wav
# Gelöscht: ./train\noise_14_var1.wav
# Gelöscht: ./train\noise_14_var2.wav
# Gelöscht: ./train\noise_14_var4.wav
# Gelöscht: ./train\noise_14_var5.wav
# Gelöscht: ./train\noise_14_var6.wav
# Gelöscht: ./train\noise_14_var7.wav
# Gelöscht: ./train\noise_14_var8.wav
# Gelöscht: ./train\noise_14_var9.wav
# Gelöscht: ./train\noise_15_var0.wav
# Gelöscht: ./train\noise_15_var1.wav
# Gelöscht: ./train\noise_15_var2.wav
# Gelöscht: ./train\noise_15_var3.wav
# Gelöscht: ./train\noise_15_var5.wav
# Gelöscht: ./train\noise_15_var6.wav
# Gelöscht: ./train\noise_15_var7.wav
# Gelöscht: ./train\noise_15_var8.wav
# Gelöscht: ./train\noise_15_var9.wav
# Gelöscht: ./train\noise_16_var0.wav
# Gelöscht: ./train\noise_16_var1.wav
# Gelöscht: ./train\noise_16_var2.wav
# Gelöscht: ./train\noise_16_var3.wav
# Gelöscht: ./train\noise_16_var4.wav
# Gelöscht: ./train\noise_16_var5.wav
# Gelöscht: ./train\noise_16_var7.wav
# Gelöscht: ./train\noise_16_var8.wav
# Gelöscht: ./train\noise_16_var9.wav
# Gelöscht: ./train\noise_17_var0.wav
# Gelöscht: ./train\noise_17_var1.wav
# Gelöscht: ./train\noise_17_var2.wav
# Gelöscht: ./train\noise_17_var5.wav
# Gelöscht: ./train\noise_17_var6.wav
# Gelöscht: ./train\noise_17_var7.wav
# Gelöscht: ./train\noise_17_var8.wav
# Gelöscht: ./train\noise_17_var9.wav
# Gelöscht: ./train\noise_18_var0.wav
# Gelöscht: ./train\noise_18_var1.wav
# Gelöscht: ./train\noise_18_var2.wav
# Gelöscht: ./train\noise_18_var3.wav
# Gelöscht: ./train\noise_18_var5.wav
# Gelöscht: ./train\noise_18_var6.wav
# Gelöscht: ./train\noise_18_var7.wav
# Gelöscht: ./train\noise_18_var8.wav
# Gelöscht: ./train\noise_19_var0.wav
# Gelöscht: ./train\noise_19_var1.wav
# Gelöscht: ./train\noise_19_var2.wav
# Gelöscht: ./train\noise_19_var3.wav
# Gelöscht: ./train\noise_19_var6.wav
# Gelöscht: ./train\noise_19_var7.wav
# Gelöscht: ./train\noise_19_var8.wav
# Gelöscht: ./train\noise_19_var9.wav
# Gelöscht: ./train\noise_1_var0.wav
# Gelöscht: ./train\noise_1_var1.wav
# Gelöscht: ./train\noise_1_var2.wav
# Gelöscht: ./train\noise_1_var3.wav
# Gelöscht: ./train\noise_1_var4.wav
# Gelöscht: ./train\noise_1_var5.wav
# Gelöscht: ./train\noise_1_var7.wav
# Gelöscht: ./train\noise_1_var8.wav
# Gelöscht: ./train\noise_1_var9.wav
# Gelöscht: ./train\noise_20_var0.wav
# Gelöscht: ./train\noise_20_var1.wav
# Gelöscht: ./train\noise_20_var2.wav
# Gelöscht: ./train\noise_20_var3.wav
# Gelöscht: ./train\noise_20_var4.wav
# Gelöscht: ./train\noise_20_var6.wav
# Gelöscht: ./train\noise_20_var7.wav
# Gelöscht: ./train\noise_20_var8.wav
# Gelöscht: ./train\noise_21_var0.wav
# Gelöscht: ./train\noise_21_var2.wav
# Gelöscht: ./train\noise_21_var3.wav
# Gelöscht: ./train\noise_21_var4.wav
# Gelöscht: ./train\noise_21_var6.wav
# Gelöscht: ./train\noise_21_var7.wav
# Gelöscht: ./train\noise_21_var9.wav
# Gelöscht: ./train\noise_22_var0.wav
# Gelöscht: ./train\noise_22_var1.wav
# Gelöscht: ./train\noise_22_var2.wav
# Gelöscht: ./train\noise_22_var3.wav
# Gelöscht: ./train\noise_22_var4.wav
# Gelöscht: ./train\noise_22_var7.wav
# Gelöscht: ./train\noise_22_var8.wav
# Gelöscht: ./train\noise_22_var9.wav
# Gelöscht: ./train\noise_23_var0.wav
# Gelöscht: ./train\noise_23_var1.wav
# Gelöscht: ./train\noise_23_var2.wav
# Gelöscht: ./train\noise_23_var4.wav
# Gelöscht: ./train\noise_23_var5.wav
# Gelöscht: ./train\noise_23_var6.wav
# Gelöscht: ./train\noise_23_var7.wav
# Gelöscht: ./train\noise_23_var8.wav
# Gelöscht: ./train\noise_23_var9.wav
# Gelöscht: ./train\noise_24_var0.wav
# Gelöscht: ./train\noise_24_var1.wav
# Gelöscht: ./train\noise_24_var2.wav
# Gelöscht: ./train\noise_24_var3.wav
# Gelöscht: ./train\noise_24_var5.wav
# Gelöscht: ./train\noise_24_var6.wav
# Gelöscht: ./train\noise_24_var7.wav
# Gelöscht: ./train\noise_24_var8.wav
# Gelöscht: ./train\noise_25_var0.wav
# Gelöscht: ./train\noise_25_var1.wav
# Gelöscht: ./train\noise_25_var2.wav
# Gelöscht: ./train\noise_25_var3.wav
# Gelöscht: ./train\noise_25_var5.wav
# Gelöscht: ./train\noise_25_var8.wav
# Gelöscht: ./train\noise_25_var9.wav
# Gelöscht: ./train\noise_26_var0.wav
# Gelöscht: ./train\noise_26_var1.wav
# Gelöscht: ./train\noise_26_var2.wav
# Gelöscht: ./train\noise_26_var3.wav
# Gelöscht: ./train\noise_26_var4.wav
# Gelöscht: ./train\noise_26_var5.wav
# Gelöscht: ./train\noise_26_var6.wav
# Gelöscht: ./train\noise_26_var7.wav
# Gelöscht: ./train\noise_26_var8.wav
# Gelöscht: ./train\noise_26_var9.wav
# Gelöscht: ./train\noise_27_var1.wav
# Gelöscht: ./train\noise_27_var2.wav
# Gelöscht: ./train\noise_27_var3.wav
# Gelöscht: ./train\noise_27_var4.wav
# Gelöscht: ./train\noise_27_var5.wav
# Gelöscht: ./train\noise_27_var6.wav
# Gelöscht: ./train\noise_27_var7.wav
# Gelöscht: ./train\noise_27_var9.wav
# Gelöscht: ./train\noise_28_var0.wav
# Gelöscht: ./train\noise_28_var1.wav
# Gelöscht: ./train\noise_28_var3.wav
# Gelöscht: ./train\noise_28_var7.wav
# Gelöscht: ./train\noise_28_var8.wav
# Gelöscht: ./train\noise_29_var0.wav
# Gelöscht: ./train\noise_29_var1.wav
# Gelöscht: ./train\noise_29_var2.wav
# Gelöscht: ./train\noise_29_var4.wav
# Gelöscht: ./train\noise_29_var5.wav
# Gelöscht: ./train\noise_29_var6.wav
# Gelöscht: ./train\noise_29_var7.wav
# Gelöscht: ./train\noise_29_var8.wav
# Gelöscht: ./train\noise_29_var9.wav
# Gelöscht: ./train\noise_2_var1.wav
# Gelöscht: ./train\noise_2_var2.wav
# Gelöscht: ./train\noise_2_var3.wav
# Gelöscht: ./train\noise_2_var5.wav
# Gelöscht: ./train\noise_2_var7.wav
# Gelöscht: ./train\noise_2_var8.wav
# Gelöscht: ./train\noise_2_var9.wav
# Gelöscht: ./train\noise_30_var1.wav
# Gelöscht: ./train\noise_30_var2.wav
# Gelöscht: ./train\noise_30_var4.wav
# Gelöscht: ./train\noise_30_var6.wav
# Gelöscht: ./train\noise_30_var8.wav
# Gelöscht: ./train\noise_30_var9.wav
# Gelöscht: ./train\noise_31_var0.wav
# Gelöscht: ./train\noise_31_var2.wav
# Gelöscht: ./train\noise_31_var3.wav
# Gelöscht: ./train\noise_31_var4.wav
# Gelöscht: ./train\noise_31_var5.wav
# Gelöscht: ./train\noise_31_var6.wav
# Gelöscht: ./train\noise_31_var7.wav
# Gelöscht: ./train\noise_31_var8.wav
# Gelöscht: ./train\noise_31_var9.wav
# Gelöscht: ./train\noise_32_var0.wav
# Gelöscht: ./train\noise_32_var1.wav
# Gelöscht: ./train\noise_32_var2.wav
# Gelöscht: ./train\noise_32_var3.wav
# Gelöscht: ./train\noise_32_var6.wav
# Gelöscht: ./train\noise_32_var7.wav
# Gelöscht: ./train\noise_32_var9.wav
# Gelöscht: ./train\noise_33_var0.wav
# Gelöscht: ./train\noise_33_var1.wav
# Gelöscht: ./train\noise_33_var2.wav
# Gelöscht: ./train\noise_33_var3.wav
# Gelöscht: ./train\noise_33_var4.wav
# Gelöscht: ./train\noise_33_var5.wav
# Gelöscht: ./train\noise_33_var6.wav
# Gelöscht: ./train\noise_33_var7.wav
# Gelöscht: ./train\noise_33_var8.wav
# Gelöscht: ./train\noise_34_var1.wav
# Gelöscht: ./train\noise_34_var2.wav
# Gelöscht: ./train\noise_34_var4.wav
# Gelöscht: ./train\noise_34_var5.wav
# Gelöscht: ./train\noise_34_var7.wav
# Gelöscht: ./train\noise_34_var8.wav
# Gelöscht: ./train\noise_34_var9.wav
# Gelöscht: ./train\noise_35_var0.wav
# Gelöscht: ./train\noise_35_var1.wav
# Gelöscht: ./train\noise_35_var2.wav
# Gelöscht: ./train\noise_35_var3.wav
# Gelöscht: ./train\noise_35_var5.wav
# Gelöscht: ./train\noise_35_var6.wav
# Gelöscht: ./train\noise_35_var7.wav
# Gelöscht: ./train\noise_35_var8.wav
# Gelöscht: ./train\noise_35_var9.wav
# Gelöscht: ./train\noise_37_var1.wav
# Gelöscht: ./train\noise_37_var2.wav
# Gelöscht: ./train\noise_37_var3.wav
# Gelöscht: ./train\noise_37_var4.wav
# Gelöscht: ./train\noise_37_var5.wav
# Gelöscht: ./train\noise_37_var6.wav
# Gelöscht: ./train\noise_37_var8.wav
# Gelöscht: ./train\noise_37_var9.wav
# Gelöscht: ./train\noise_39_var1.wav
# Gelöscht: ./train\noise_39_var2.wav
# Gelöscht: ./train\noise_39_var3.wav
# Gelöscht: ./train\noise_39_var5.wav
# Gelöscht: ./train\noise_39_var6.wav
# Gelöscht: ./train\noise_39_var7.wav
# Gelöscht: ./train\noise_39_var8.wav
# Gelöscht: ./train\noise_39_var9.wav
# Gelöscht: ./train\noise_3_var0.wav
# Gelöscht: ./train\noise_3_var2.wav
# Gelöscht: ./train\noise_3_var3.wav
# Gelöscht: ./train\noise_3_var6.wav
# Gelöscht: ./train\noise_3_var7.wav
# Gelöscht: ./train\noise_3_var8.wav
# Gelöscht: ./train\noise_3_var9.wav
# Gelöscht: ./train\noise_40_var0.wav
# Gelöscht: ./train\noise_40_var1.wav
# Gelöscht: ./train\noise_40_var2.wav
# Gelöscht: ./train\noise_40_var3.wav
# Gelöscht: ./train\noise_40_var4.wav
# Gelöscht: ./train\noise_40_var6.wav
# Gelöscht: ./train\noise_40_var7.wav
# Gelöscht: ./train\noise_40_var8.wav
# Gelöscht: ./train\noise_40_var9.wav
# Gelöscht: ./train\noise_41_var0.wav
# Gelöscht: ./train\noise_41_var2.wav
# Gelöscht: ./train\noise_41_var3.wav
# Gelöscht: ./train\noise_41_var4.wav
# Gelöscht: ./train\noise_41_var5.wav
# Gelöscht: ./train\noise_41_var6.wav
# Gelöscht: ./train\noise_41_var7.wav
# Gelöscht: ./train\noise_41_var8.wav
# Gelöscht: ./train\noise_41_var9.wav
# Gelöscht: ./train\noise_42_var0.wav
# Gelöscht: ./train\noise_42_var2.wav
# Gelöscht: ./train\noise_42_var3.wav
# Gelöscht: ./train\noise_42_var4.wav
# Gelöscht: ./train\noise_42_var5.wav
# Gelöscht: ./train\noise_42_var6.wav
# Gelöscht: ./train\noise_42_var8.wav
# Gelöscht: ./train\noise_42_var9.wav
# Gelöscht: ./train\noise_43_var1.wav
# Gelöscht: ./train\noise_43_var2.wav
# Gelöscht: ./train\noise_43_var5.wav
# Gelöscht: ./train\noise_43_var8.wav
# Gelöscht: ./train\noise_43_var9.wav
# Gelöscht: ./train\noise_44_var0.wav
# Gelöscht: ./train\noise_44_var1.wav
# Gelöscht: ./train\noise_44_var3.wav
# Gelöscht: ./train\noise_44_var4.wav
# Gelöscht: ./train\noise_44_var6.wav
# Gelöscht: ./train\noise_44_var9.wav
# Gelöscht: ./train\noise_45_var0.wav
# Gelöscht: ./train\noise_45_var1.wav
# Gelöscht: ./train\noise_45_var4.wav
# Gelöscht: ./train\noise_45_var6.wav
# Gelöscht: ./train\noise_45_var7.wav
# Gelöscht: ./train\noise_45_var9.wav
# Gelöscht: ./train\noise_46_var0.wav
# Gelöscht: ./train\noise_46_var1.wav
# Gelöscht: ./train\noise_46_var2.wav
# Gelöscht: ./train\noise_46_var3.wav
# Gelöscht: ./train\noise_46_var4.wav
# Gelöscht: ./train\noise_46_var5.wav
# Gelöscht: ./train\noise_46_var6.wav
# Gelöscht: ./train\noise_46_var7.wav
# Gelöscht: ./train\noise_46_var8.wav
# Gelöscht: ./train\noise_46_var9.wav
# Gelöscht: ./train\noise_47_var0.wav
# Gelöscht: ./train\noise_47_var4.wav
# Gelöscht: ./train\noise_47_var5.wav
# Gelöscht: ./train\noise_47_var6.wav
# Gelöscht: ./train\noise_47_var7.wav
# Gelöscht: ./train\noise_47_var8.wav
# Gelöscht: ./train\noise_48_var0.wav
# Gelöscht: ./train\noise_48_var1.wav
# Gelöscht: ./train\noise_48_var2.wav
# Gelöscht: ./train\noise_48_var5.wav
# Gelöscht: ./train\noise_48_var6.wav
# Gelöscht: ./train\noise_48_var7.wav
# Gelöscht: ./train\noise_48_var8.wav
# Gelöscht: ./train\noise_48_var9.wav
# Gelöscht: ./train\noise_49_var0.wav
# Gelöscht: ./train\noise_49_var1.wav
# Gelöscht: ./train\noise_49_var2.wav
# Gelöscht: ./train\noise_49_var3.wav
# Gelöscht: ./train\noise_49_var4.wav
# Gelöscht: ./train\noise_49_var5.wav
# Gelöscht: ./train\noise_49_var6.wav
# Gelöscht: ./train\noise_49_var8.wav
# Gelöscht: ./train\noise_49_var9.wav
# Gelöscht: ./train\noise_4_var0.wav
# Gelöscht: ./train\noise_4_var2.wav
# Gelöscht: ./train\noise_4_var3.wav
# Gelöscht: ./train\noise_4_var4.wav
# Gelöscht: ./train\noise_4_var6.wav
# Gelöscht: ./train\noise_4_var7.wav
# Gelöscht: ./train\noise_4_var8.wav
# Gelöscht: ./train\noise_4_var9.wav
# Gelöscht: ./train\noise_50_var0.wav
# Gelöscht: ./train\noise_50_var2.wav
# Gelöscht: ./train\noise_50_var3.wav
# Gelöscht: ./train\noise_50_var4.wav
# Gelöscht: ./train\noise_50_var5.wav
# Gelöscht: ./train\noise_50_var6.wav
# Gelöscht: ./train\noise_50_var7.wav
# Gelöscht: ./train\noise_50_var8.wav
# Gelöscht: ./train\noise_50_var9.wav
# Gelöscht: ./train\noise_51_var0.wav
# Gelöscht: ./train\noise_51_var2.wav
# Gelöscht: ./train\noise_51_var3.wav
# Gelöscht: ./train\noise_51_var4.wav
# Gelöscht: ./train\noise_51_var5.wav
# Gelöscht: ./train\noise_51_var8.wav
# Gelöscht: ./train\noise_51_var9.wav
# Gelöscht: ./train\noise_52_var0.wav
# Gelöscht: ./train\noise_52_var1.wav
# Gelöscht: ./train\noise_52_var2.wav
# Gelöscht: ./train\noise_52_var3.wav
# Gelöscht: ./train\noise_52_var4.wav
# Gelöscht: ./train\noise_52_var7.wav
# Gelöscht: ./train\noise_52_var8.wav
# Gelöscht: ./train\noise_52_var9.wav
# Gelöscht: ./train\noise_53_var0.wav
# Gelöscht: ./train\noise_53_var1.wav
# Gelöscht: ./train\noise_53_var2.wav
# Gelöscht: ./train\noise_53_var5.wav
# Gelöscht: ./train\noise_53_var6.wav
# Gelöscht: ./train\noise_53_var7.wav
# Gelöscht: ./train\noise_53_var8.wav
# Gelöscht: ./train\noise_53_var9.wav
# Gelöscht: ./train\noise_54_var0.wav
# Gelöscht: ./train\noise_54_var1.wav
# Gelöscht: ./train\noise_54_var2.wav
# Gelöscht: ./train\noise_54_var3.wav
# Gelöscht: ./train\noise_54_var4.wav
# Gelöscht: ./train\noise_54_var7.wav
# Gelöscht: ./train\noise_55_var0.wav
# Gelöscht: ./train\noise_55_var1.wav
# Gelöscht: ./train\noise_55_var2.wav
# Gelöscht: ./train\noise_55_var4.wav
# Gelöscht: ./train\noise_55_var5.wav
# Gelöscht: ./train\noise_55_var6.wav
# Gelöscht: ./train\noise_55_var7.wav
# Gelöscht: ./train\noise_55_var8.wav
# Gelöscht: ./train\noise_55_var9.wav
# Gelöscht: ./train\noise_56_var0.wav
# Gelöscht: ./train\noise_56_var1.wav
# Gelöscht: ./train\noise_56_var2.wav
# Gelöscht: ./train\noise_56_var3.wav
# Gelöscht: ./train\noise_56_var4.wav
# Gelöscht: ./train\noise_56_var5.wav
# Gelöscht: ./train\noise_56_var6.wav
# Gelöscht: ./train\noise_56_var7.wav
# Gelöscht: ./train\noise_56_var9.wav
# Gelöscht: ./train\noise_57_var0.wav
# Gelöscht: ./train\noise_57_var1.wav
# Gelöscht: ./train\noise_57_var3.wav
# Gelöscht: ./train\noise_57_var4.wav
# Gelöscht: ./train\noise_57_var5.wav
# Gelöscht: ./train\noise_57_var6.wav
# Gelöscht: ./train\noise_57_var8.wav
# Gelöscht: ./train\noise_57_var9.wav
# Gelöscht: ./train\noise_58_var0.wav
# Gelöscht: ./train\noise_58_var1.wav
# Gelöscht: ./train\noise_58_var2.wav
# Gelöscht: ./train\noise_58_var3.wav
# Gelöscht: ./train\noise_58_var4.wav
# Gelöscht: ./train\noise_58_var5.wav
# Gelöscht: ./train\noise_58_var7.wav
# Gelöscht: ./train\noise_58_var8.wav
# Gelöscht: ./train\noise_58_var9.wav
# Gelöscht: ./train\noise_59_var0.wav
# Gelöscht: ./train\noise_59_var2.wav
# Gelöscht: ./train\noise_59_var3.wav
# Gelöscht: ./train\noise_59_var4.wav
# Gelöscht: ./train\noise_59_var6.wav
# Gelöscht: ./train\noise_59_var7.wav
# Gelöscht: ./train\noise_59_var8.wav
# Gelöscht: ./train\noise_59_var9.wav
# Gelöscht: ./train\noise_5_var0.wav
# Gelöscht: ./train\noise_5_var1.wav
# Gelöscht: ./train\noise_5_var2.wav
# Gelöscht: ./train\noise_5_var4.wav
# Gelöscht: ./train\noise_5_var5.wav
# Gelöscht: ./train\noise_5_var6.wav
# Gelöscht: ./train\noise_5_var7.wav
# Gelöscht: ./train\noise_5_var9.wav
# Gelöscht: ./train\noise_60_var0.wav
# Gelöscht: ./train\noise_60_var1.wav
# Gelöscht: ./train\noise_60_var2.wav
# Gelöscht: ./train\noise_60_var4.wav
# Gelöscht: ./train\noise_60_var5.wav
# Gelöscht: ./train\noise_60_var6.wav
# Gelöscht: ./train\noise_60_var7.wav
# Gelöscht: ./train\noise_60_var8.wav
# Gelöscht: ./train\noise_60_var9.wav
# Gelöscht: ./train\noise_62_var0.wav
# Gelöscht: ./train\noise_62_var2.wav
# Gelöscht: ./train\noise_62_var3.wav
# Gelöscht: ./train\noise_62_var4.wav
# Gelöscht: ./train\noise_62_var5.wav
# Gelöscht: ./train\noise_62_var6.wav
# Gelöscht: ./train\noise_62_var7.wav
# Gelöscht: ./train\noise_62_var8.wav
# Gelöscht: ./train\noise_62_var9.wav
# Gelöscht: ./train\noise_63_var0.wav
# Gelöscht: ./train\noise_63_var2.wav
# Gelöscht: ./train\noise_63_var4.wav
# Gelöscht: ./train\noise_63_var5.wav
# Gelöscht: ./train\noise_63_var7.wav
# Gelöscht: ./train\noise_63_var9.wav
# Gelöscht: ./train\noise_64_var0.wav
# Gelöscht: ./train\noise_64_var1.wav
# Gelöscht: ./train\noise_64_var3.wav
# Gelöscht: ./train\noise_64_var4.wav
# Gelöscht: ./train\noise_64_var7.wav
# Gelöscht: ./train\noise_64_var8.wav
# Gelöscht: ./train\noise_64_var9.wav
# Gelöscht: ./train\noise_65_var0.wav
# Gelöscht: ./train\noise_65_var1.wav
# Gelöscht: ./train\noise_65_var3.wav
# Gelöscht: ./train\noise_65_var4.wav
# Gelöscht: ./train\noise_65_var6.wav
# Gelöscht: ./train\noise_65_var8.wav
# Gelöscht: ./train\noise_65_var9.wav
# Gelöscht: ./train\noise_66_var1.wav
# Gelöscht: ./train\noise_66_var2.wav
# Gelöscht: ./train\noise_66_var3.wav
# Gelöscht: ./train\noise_66_var4.wav
# Gelöscht: ./train\noise_66_var5.wav
# Gelöscht: ./train\noise_66_var6.wav
# Gelöscht: ./train\noise_66_var7.wav
# Gelöscht: ./train\noise_66_var8.wav
# Gelöscht: ./train\noise_66_var9.wav
# Gelöscht: ./train\noise_67_var0.wav
# Gelöscht: ./train\noise_67_var2.wav
# Gelöscht: ./train\noise_67_var3.wav
# Gelöscht: ./train\noise_67_var6.wav
# Gelöscht: ./train\noise_67_var7.wav
# Gelöscht: ./train\noise_67_var8.wav
# Gelöscht: ./train\noise_68_var0.wav
# Gelöscht: ./train\noise_68_var3.wav
# Gelöscht: ./train\noise_68_var4.wav
# Gelöscht: ./train\noise_68_var6.wav
# Gelöscht: ./train\noise_68_var7.wav
# Gelöscht: ./train\noise_68_var8.wav
# Gelöscht: ./train\noise_68_var9.wav
# Gelöscht: ./train\noise_69_var0.wav
# Gelöscht: ./train\noise_69_var1.wav
# Gelöscht: ./train\noise_69_var2.wav
# Gelöscht: ./train\noise_69_var3.wav
# Gelöscht: ./train\noise_69_var4.wav
# Gelöscht: ./train\noise_69_var6.wav
# Gelöscht: ./train\noise_69_var7.wav
# Gelöscht: ./train\noise_69_var9.wav
# Gelöscht: ./train\noise_6_var0.wav
# Gelöscht: ./train\noise_6_var1.wav
# Gelöscht: ./train\noise_6_var2.wav
# Gelöscht: ./train\noise_6_var3.wav
# Gelöscht: ./train\noise_6_var4.wav
# Gelöscht: ./train\noise_6_var5.wav
# Gelöscht: ./train\noise_6_var6.wav
# Gelöscht: ./train\noise_6_var7.wav
# Gelöscht: ./train\noise_6_var8.wav
# Gelöscht: ./train\noise_6_var9.wav
# Gelöscht: ./train\noise_71_var0.wav
# Gelöscht: ./train\noise_71_var1.wav
# Gelöscht: ./train\noise_71_var2.wav
# Gelöscht: ./train\noise_71_var3.wav
# Gelöscht: ./train\noise_71_var4.wav
# Gelöscht: ./train\noise_71_var6.wav
# Gelöscht: ./train\noise_71_var7.wav
# Gelöscht: ./train\noise_71_var8.wav
# Gelöscht: ./train\noise_71_var9.wav
# Gelöscht: ./train\noise_72_var0.wav
# Gelöscht: ./train\noise_72_var1.wav
# Gelöscht: ./train\noise_72_var2.wav
# Gelöscht: ./train\noise_72_var3.wav
# Gelöscht: ./train\noise_72_var4.wav
# Gelöscht: ./train\noise_72_var5.wav
# Gelöscht: ./train\noise_72_var6.wav
# Gelöscht: ./train\noise_72_var7.wav
# Gelöscht: ./train\noise_72_var9.wav
# Gelöscht: ./train\noise_73_var0.wav
# Gelöscht: ./train\noise_73_var1.wav
# Gelöscht: ./train\noise_73_var2.wav
# Gelöscht: ./train\noise_73_var3.wav
# Gelöscht: ./train\noise_73_var4.wav
# Gelöscht: ./train\noise_73_var5.wav
# Gelöscht: ./train\noise_73_var7.wav
# Gelöscht: ./train\noise_73_var8.wav
# Gelöscht: ./train\noise_73_var9.wav
# Gelöscht: ./train\noise_74_var0.wav
# Gelöscht: ./train\noise_74_var2.wav
# Gelöscht: ./train\noise_74_var3.wav
# Gelöscht: ./train\noise_74_var4.wav
# Gelöscht: ./train\noise_74_var5.wav
# Gelöscht: ./train\noise_74_var7.wav
# Gelöscht: ./train\noise_74_var8.wav
# Gelöscht: ./train\noise_74_var9.wav
# Gelöscht: ./train\noise_75_var0.wav
# Gelöscht: ./train\noise_75_var2.wav
# Gelöscht: ./train\noise_75_var3.wav
# Gelöscht: ./train\noise_75_var4.wav
# Gelöscht: ./train\noise_75_var7.wav
# Gelöscht: ./train\noise_75_var9.wav
# Gelöscht: ./train\noise_76_var1.wav
# Gelöscht: ./train\noise_76_var4.wav
# Gelöscht: ./train\noise_76_var7.wav
# Gelöscht: ./train\noise_76_var8.wav
# Gelöscht: ./train\noise_76_var9.wav
# Gelöscht: ./train\noise_77_var0.wav
# Gelöscht: ./train\noise_77_var1.wav
# Gelöscht: ./train\noise_77_var2.wav
# Gelöscht: ./train\noise_77_var3.wav
# Gelöscht: ./train\noise_77_var5.wav
# Gelöscht: ./train\noise_77_var8.wav
# Gelöscht: ./train\noise_78_var1.wav
# Gelöscht: ./train\noise_78_var2.wav
# Gelöscht: ./train\noise_78_var3.wav
# Gelöscht: ./train\noise_78_var4.wav
# Gelöscht: ./train\noise_78_var5.wav
# Gelöscht: ./train\noise_78_var6.wav
# Gelöscht: ./train\noise_78_var7.wav
# Gelöscht: ./train\noise_78_var9.wav
# Gelöscht: ./train\noise_79_var0.wav
# Gelöscht: ./train\noise_79_var1.wav
# Gelöscht: ./train\noise_79_var2.wav
# Gelöscht: ./train\noise_79_var3.wav
# Gelöscht: ./train\noise_79_var4.wav
# Gelöscht: ./train\noise_79_var5.wav
# Gelöscht: ./train\noise_79_var6.wav
# Gelöscht: ./train\noise_79_var8.wav
# Gelöscht: ./train\noise_79_var9.wav
# Gelöscht: ./train\noise_7_var0.wav
# Gelöscht: ./train\noise_7_var1.wav
# Gelöscht: ./train\noise_7_var2.wav
# Gelöscht: ./train\noise_7_var3.wav
# Gelöscht: ./train\noise_7_var4.wav
# Gelöscht: ./train\noise_7_var5.wav
# Gelöscht: ./train\noise_7_var6.wav
# Gelöscht: ./train\noise_7_var7.wav
# Gelöscht: ./train\noise_7_var8.wav
# Gelöscht: ./train\noise_7_var9.wav
# Gelöscht: ./train\noise_80_var1.wav
# Gelöscht: ./train\noise_80_var2.wav
# Gelöscht: ./train\noise_80_var3.wav
# Gelöscht: ./train\noise_80_var4.wav
# Gelöscht: ./train\noise_80_var5.wav
# Gelöscht: ./train\noise_80_var7.wav
# Gelöscht: ./train\noise_80_var9.wav
# Gelöscht: ./train\noise_81_var0.wav
# Gelöscht: ./train\noise_81_var2.wav
# Gelöscht: ./train\noise_81_var3.wav
# Gelöscht: ./train\noise_81_var5.wav
# Gelöscht: ./train\noise_81_var6.wav
# Gelöscht: ./train\noise_81_var7.wav
# Gelöscht: ./train\noise_81_var9.wav
# Gelöscht: ./train\noise_82_var0.wav
# Gelöscht: ./train\noise_82_var5.wav
# Gelöscht: ./train\noise_82_var6.wav
# Gelöscht: ./train\noise_82_var9.wav
# Gelöscht: ./train\noise_83_var0.wav
# Gelöscht: ./train\noise_83_var1.wav
# Gelöscht: ./train\noise_83_var2.wav
# Gelöscht: ./train\noise_83_var3.wav
# Gelöscht: ./train\noise_83_var5.wav
# Gelöscht: ./train\noise_83_var6.wav
# Gelöscht: ./train\noise_83_var7.wav
# Gelöscht: ./train\noise_83_var8.wav
# Gelöscht: ./train\noise_83_var9.wav
# Gelöscht: ./train\noise_85_var0.wav
# Gelöscht: ./train\noise_85_var1.wav
# Gelöscht: ./train\noise_85_var2.wav
# Gelöscht: ./train\noise_85_var3.wav
# Gelöscht: ./train\noise_85_var4.wav
# Gelöscht: ./train\noise_85_var5.wav
# Gelöscht: ./train\noise_85_var6.wav
# Gelöscht: ./train\noise_85_var7.wav
# Gelöscht: ./train\noise_85_var9.wav
# Gelöscht: ./train\noise_86_var0.wav
# Gelöscht: ./train\noise_86_var1.wav
# Gelöscht: ./train\noise_86_var2.wav
# Gelöscht: ./train\noise_86_var3.wav
# Gelöscht: ./train\noise_86_var4.wav
# Gelöscht: ./train\noise_86_var5.wav
# Gelöscht: ./train\noise_86_var6.wav
# Gelöscht: ./train\noise_87_var0.wav
# Gelöscht: ./train\noise_87_var1.wav
# Gelöscht: ./train\noise_87_var2.wav
# Gelöscht: ./train\noise_87_var3.wav
# Gelöscht: ./train\noise_87_var4.wav
# Gelöscht: ./train\noise_87_var5.wav
# Gelöscht: ./train\noise_87_var6.wav
# Gelöscht: ./train\noise_87_var7.wav
# Gelöscht: ./train\noise_87_var8.wav
# Gelöscht: ./train\noise_87_var9.wav
# Gelöscht: ./train\noise_88_var0.wav
# Gelöscht: ./train\noise_88_var2.wav
# Gelöscht: ./train\noise_88_var4.wav
# Gelöscht: ./train\noise_88_var5.wav
# Gelöscht: ./train\noise_88_var6.wav
# Gelöscht: ./train\noise_88_var7.wav
# Gelöscht: ./train\noise_88_var8.wav
# Gelöscht: ./train\noise_88_var9.wav
# Gelöscht: ./train\noise_89_var0.wav
# Gelöscht: ./train\noise_89_var1.wav
# Gelöscht: ./train\noise_89_var2.wav
# Gelöscht: ./train\noise_89_var3.wav
# Gelöscht: ./train\noise_89_var4.wav
# Gelöscht: ./train\noise_89_var6.wav
# Gelöscht: ./train\noise_89_var7.wav
# Gelöscht: ./train\noise_89_var8.wav
# Gelöscht: ./train\noise_8_var0.wav
# Gelöscht: ./train\noise_8_var1.wav
# Gelöscht: ./train\noise_8_var2.wav
# Gelöscht: ./train\noise_8_var4.wav
# Gelöscht: ./train\noise_8_var5.wav
# Gelöscht: ./train\noise_8_var6.wav
# Gelöscht: ./train\noise_8_var7.wav
# Gelöscht: ./train\noise_8_var8.wav
# Gelöscht: ./train\noise_8_var9.wav
# Gelöscht: ./train\noise_90_var3.wav
# Gelöscht: ./train\noise_90_var4.wav
# Gelöscht: ./train\noise_90_var5.wav
# Gelöscht: ./train\noise_90_var6.wav
# Gelöscht: ./train\noise_90_var7.wav
# Gelöscht: ./train\noise_90_var8.wav
# Gelöscht: ./train\noise_90_var9.wav
# Gelöscht: ./train\noise_91_var0.wav
# Gelöscht: ./train\noise_91_var1.wav
# Gelöscht: ./train\noise_91_var2.wav
# Gelöscht: ./train\noise_91_var3.wav
# Gelöscht: ./train\noise_91_var4.wav
# Gelöscht: ./train\noise_91_var5.wav
# Gelöscht: ./train\noise_91_var6.wav
# Gelöscht: ./train\noise_91_var7.wav
# Gelöscht: ./train\noise_91_var9.wav
# Gelöscht: ./train\noise_92_var0.wav
# Gelöscht: ./train\noise_92_var1.wav
# Gelöscht: ./train\noise_92_var2.wav
# Gelöscht: ./train\noise_92_var3.wav
# Gelöscht: ./train\noise_92_var5.wav
# Gelöscht: ./train\noise_92_var6.wav
# Gelöscht: ./train\noise_92_var7.wav
# Gelöscht: ./train\noise_92_var8.wav
# Gelöscht: ./train\noise_92_var9.wav
# Gelöscht: ./train\noise_93_var0.wav
# Gelöscht: ./train\noise_93_var1.wav
# Gelöscht: ./train\noise_93_var2.wav
# Gelöscht: ./train\noise_93_var3.wav
# Gelöscht: ./train\noise_93_var4.wav
# Gelöscht: ./train\noise_93_var5.wav
# Gelöscht: ./train\noise_93_var6.wav
# Gelöscht: ./train\noise_93_var7.wav
# Gelöscht: ./train\noise_93_var9.wav
# Gelöscht: ./train\noise_94_var0.wav
# Gelöscht: ./train\noise_94_var1.wav
# Gelöscht: ./train\noise_94_var2.wav
# Gelöscht: ./train\noise_94_var3.wav
# Gelöscht: ./train\noise_94_var4.wav
# Gelöscht: ./train\noise_94_var5.wav
# Gelöscht: ./train\noise_94_var6.wav
# Gelöscht: ./train\noise_94_var8.wav
# Gelöscht: ./train\noise_94_var9.wav
# Gelöscht: ./train\noise_95_var1.wav
# Gelöscht: ./train\noise_95_var2.wav
# Gelöscht: ./train\noise_95_var3.wav
# Gelöscht: ./train\noise_95_var4.wav
# Gelöscht: ./train\noise_95_var6.wav
# Gelöscht: ./train\noise_95_var7.wav
# Gelöscht: ./train\noise_95_var8.wav
# Gelöscht: ./train\noise_95_var9.wav
# Gelöscht: ./train\noise_96_var1.wav
# Gelöscht: ./train\noise_96_var2.wav
# Gelöscht: ./train\noise_96_var3.wav
# Gelöscht: ./train\noise_96_var4.wav
# Gelöscht: ./train\noise_96_var6.wav
# Gelöscht: ./train\noise_96_var7.wav
# Gelöscht: ./train\noise_96_var8.wav
# Gelöscht: ./train\noise_96_var9.wav
# Gelöscht: ./train\noise_97_var0.wav
# Gelöscht: ./train\noise_97_var1.wav
# Gelöscht: ./train\noise_97_var3.wav
# Gelöscht: ./train\noise_97_var4.wav
# Gelöscht: ./train\noise_97_var5.wav
# Gelöscht: ./train\noise_97_var6.wav
# Gelöscht: ./train\noise_97_var7.wav
# Gelöscht: ./train\noise_97_var8.wav
# Gelöscht: ./train\noise_98_var0.wav
# Gelöscht: ./train\noise_98_var1.wav
# Gelöscht: ./train\noise_98_var2.wav
# Gelöscht: ./train\noise_98_var4.wav
# Gelöscht: ./train\noise_98_var5.wav
# Gelöscht: ./train\noise_98_var7.wav
# Gelöscht: ./train\noise_98_var8.wav
# Gelöscht: ./train\noise_98_var9.wav
# Gelöscht: ./train\noise_99_var0.wav
# Gelöscht: ./train\noise_99_var4.wav
# Gelöscht: ./train\noise_99_var5.wav
# Gelöscht: ./train\noise_99_var7.wav
# Gelöscht: ./train\noise_99_var8.wav
# Gelöscht: ./train\noise_9_var0.wav
# Gelöscht: ./train\noise_9_var2.wav
# Gelöscht: ./train\noise_9_var5.wav
# Gelöscht: ./train\noise_9_var6.wav
# Gelöscht: ./train\noise_9_var7.wav
# Gelöscht: ./validation\knock_10_var2.wav
# Gelöscht: ./validation\knock_10_var4.wav
# Gelöscht: ./validation\knock_11_var1.wav
# Gelöscht: ./validation\knock_11_var3.wav
# Gelöscht: ./validation\knock_11_var6.wav
# Gelöscht: ./validation\knock_1_var0.wav
# Gelöscht: ./validation\knock_1_var3.wav
# Gelöscht: ./validation\knock_1_var7.wav
# Gelöscht: ./validation\knock_2_var5.wav
# Gelöscht: ./validation\knock_2_var9.wav
# Gelöscht: ./validation\knock_4_var8.wav
# Gelöscht: ./validation\knock_6_var3.wav
# Gelöscht: ./validation\knock_8_var2.wav
# Gelöscht: ./validation\knock_8_var3.wav
# Gelöscht: ./validation\knock_8_var8.wav
# Gelöscht: ./validation\knock_9_var5.wav
# Gelöscht: ./validation\knock_9_var6.wav
# Gelöscht: ./validation\knock_9_var7.wav
# Gelöscht: ./validation\knock_9_var8.wav
# Gelöscht: ./validation\knock_9_var9.wav
# Gelöscht: ./validation\knock_with_noise_10_var4.wav
# Gelöscht: ./validation\knock_with_noise_10_var5.wav
# Gelöscht: ./validation\knock_with_noise_10_var6.wav
# Gelöscht: ./validation\knock_with_noise_10_var7.wav
# Gelöscht: ./validation\knock_with_noise_11_var0.wav
# Gelöscht: ./validation\knock_with_noise_11_var3.wav
# Gelöscht: ./validation\knock_with_noise_11_var5.wav
# Gelöscht: ./validation\knock_with_noise_11_var9.wav
# Gelöscht: ./validation\knock_with_noise_12_var5.wav
# Gelöscht: ./validation\knock_with_noise_12_var8.wav
# Gelöscht: ./validation\knock_with_noise_13_var0.wav
# Gelöscht: ./validation\knock_with_noise_13_var8.wav
# Gelöscht: ./validation\knock_with_noise_14_var9.wav
# Gelöscht: ./validation\knock_with_noise_15_var2.wav
# Gelöscht: ./validation\knock_with_noise_15_var3.wav
# Gelöscht: ./validation\knock_with_noise_15_var4.wav
# Gelöscht: ./validation\knock_with_noise_15_var9.wav
# Gelöscht: ./validation\knock_with_noise_17_var6.wav
# Gelöscht: ./validation\knock_with_noise_18_var1.wav
# Gelöscht: ./validation\knock_with_noise_18_var6.wav
# Gelöscht: ./validation\knock_with_noise_18_var7.wav
# Gelöscht: ./validation\knock_with_noise_19_var1.wav
# Gelöscht: ./validation\knock_with_noise_1_var2.wav
# Gelöscht: ./validation\knock_with_noise_1_var4.wav
# Gelöscht: ./validation\knock_with_noise_21_var2.wav
# Gelöscht: ./validation\knock_with_noise_21_var4.wav
# Gelöscht: ./validation\knock_with_noise_21_var5.wav
# Gelöscht: ./validation\knock_with_noise_22_var7.wav
# Gelöscht: ./validation\knock_with_noise_23_var4.wav
# Gelöscht: ./validation\knock_with_noise_25_var3.wav
# Gelöscht: ./validation\knock_with_noise_25_var7.wav
# Gelöscht: ./validation\knock_with_noise_26_var1.wav
# Gelöscht: ./validation\knock_with_noise_26_var2.wav
# Gelöscht: ./validation\knock_with_noise_26_var5.wav
# Gelöscht: ./validation\knock_with_noise_26_var6.wav
# Gelöscht: ./validation\knock_with_noise_26_var9.wav
# Gelöscht: ./validation\knock_with_noise_27_var5.wav
# Gelöscht: ./validation\knock_with_noise_27_var6.wav
# Gelöscht: ./validation\knock_with_noise_27_var8.wav
# Gelöscht: ./validation\knock_with_noise_2_var1.wav
# Gelöscht: ./validation\knock_with_noise_2_var8.wav
# Gelöscht: ./validation\knock_with_noise_30_var3.wav
# Gelöscht: ./validation\knock_with_noise_30_var4.wav
# Gelöscht: ./validation\knock_with_noise_30_var7.wav
# Gelöscht: ./validation\knock_with_noise_31_var1.wav
# Gelöscht: ./validation\knock_with_noise_31_var2.wav
# Gelöscht: ./validation\knock_with_noise_31_var5.wav
# Gelöscht: ./validation\knock_with_noise_31_var9.wav
# Gelöscht: ./validation\knock_with_noise_32_var9.wav
# Gelöscht: ./validation\knock_with_noise_33_var2.wav
# Gelöscht: ./validation\knock_with_noise_33_var4.wav
# Gelöscht: ./validation\knock_with_noise_33_var9.wav
# Gelöscht: ./validation\knock_with_noise_35_var2.wav
# Gelöscht: ./validation\knock_with_noise_35_var5.wav
# Gelöscht: ./validation\knock_with_noise_35_var6.wav
# Gelöscht: ./validation\knock_with_noise_35_var7.wav
# Gelöscht: ./validation\knock_with_noise_36_var3.wav
# Gelöscht: ./validation\knock_with_noise_36_var7.wav
# Gelöscht: ./validation\knock_with_noise_36_var9.wav
# Gelöscht: ./validation\knock_with_noise_37_var3.wav
# Gelöscht: ./validation\knock_with_noise_37_var7.wav
# Gelöscht: ./validation\knock_with_noise_38_var4.wav
# Gelöscht: ./validation\knock_with_noise_38_var7.wav
# Gelöscht: ./validation\knock_with_noise_39_var6.wav
# Gelöscht: ./validation\knock_with_noise_39_var9.wav
# Gelöscht: ./validation\knock_with_noise_3_var2.wav
# Gelöscht: ./validation\knock_with_noise_3_var3.wav
# Gelöscht: ./validation\knock_with_noise_3_var5.wav
# Gelöscht: ./validation\knock_with_noise_3_var8.wav
# Gelöscht: ./validation\knock_with_noise_40_var0.wav
# Gelöscht: ./validation\knock_with_noise_40_var3.wav
# Gelöscht: ./validation\knock_with_noise_40_var7.wav
# Gelöscht: ./validation\knock_with_noise_41_var1.wav
# Gelöscht: ./validation\knock_with_noise_41_var3.wav
# Gelöscht: ./validation\knock_with_noise_41_var6.wav
# Gelöscht: ./validation\knock_with_noise_43_var4.wav
# Gelöscht: ./validation\knock_with_noise_43_var9.wav
# Gelöscht: ./validation\knock_with_noise_44_var1.wav
# Gelöscht: ./validation\knock_with_noise_44_var2.wav
# Gelöscht: ./validation\knock_with_noise_44_var5.wav
# Gelöscht: ./validation\knock_with_noise_46_var3.wav
# Gelöscht: ./validation\knock_with_noise_46_var7.wav
# Gelöscht: ./validation\knock_with_noise_46_var8.wav
# Gelöscht: ./validation\knock_with_noise_47_var9.wav
# Gelöscht: ./validation\knock_with_noise_49_var5.wav
# Gelöscht: ./validation\knock_with_noise_4_var1.wav
# Gelöscht: ./validation\knock_with_noise_4_var5.wav
# Gelöscht: ./validation\knock_with_noise_4_var8.wav
# Gelöscht: ./validation\knock_with_noise_5_var2.wav
# Gelöscht: ./validation\knock_with_noise_5_var9.wav
# Gelöscht: ./validation\knock_with_noise_6_var1.wav
# Gelöscht: ./validation\knock_with_noise_6_var8.wav
# Gelöscht: ./validation\knock_with_noise_7_var3.wav
# Gelöscht: ./validation\knock_with_noise_7_var4.wav
# Gelöscht: ./validation\knock_with_noise_7_var8.wav
# Gelöscht: ./validation\knock_with_noise_8_var3.wav
# Gelöscht: ./validation\noise_100_var2.wav
# Gelöscht: ./validation\noise_10_var8.wav
# Gelöscht: ./validation\noise_11_var1.wav
# Gelöscht: ./validation\noise_11_var5.wav
# Gelöscht: ./validation\noise_12_var8.wav
# Gelöscht: ./validation\noise_13_var8.wav
# Gelöscht: ./validation\noise_15_var4.wav
# Gelöscht: ./validation\noise_16_var6.wav
# Gelöscht: ./validation\noise_17_var3.wav
# Gelöscht: ./validation\noise_17_var4.wav
# Gelöscht: ./validation\noise_18_var4.wav
# Gelöscht: ./validation\noise_18_var9.wav
# Gelöscht: ./validation\noise_19_var4.wav
# Gelöscht: ./validation\noise_19_var5.wav
# Gelöscht: ./validation\noise_1_var6.wav
# Gelöscht: ./validation\noise_20_var5.wav
# Gelöscht: ./validation\noise_20_var9.wav
# Gelöscht: ./validation\noise_21_var1.wav
# Gelöscht: ./validation\noise_21_var5.wav
# Gelöscht: ./validation\noise_21_var8.wav
# Gelöscht: ./validation\noise_22_var5.wav
# Gelöscht: ./validation\noise_22_var6.wav
# Gelöscht: ./validation\noise_23_var3.wav
# Gelöscht: ./validation\noise_24_var9.wav
# Gelöscht: ./validation\noise_25_var4.wav
# Gelöscht: ./validation\noise_25_var6.wav
# Gelöscht: ./validation\noise_25_var7.wav
# Gelöscht: ./validation\noise_27_var0.wav
# Gelöscht: ./validation\noise_27_var8.wav
# Gelöscht: ./validation\noise_28_var2.wav
# Gelöscht: ./validation\noise_28_var4.wav
# Gelöscht: ./validation\noise_28_var5.wav
# Gelöscht: ./validation\noise_28_var6.wav
# Gelöscht: ./validation\noise_28_var9.wav
# Gelöscht: ./validation\noise_29_var3.wav
# Gelöscht: ./validation\noise_2_var0.wav
# Gelöscht: ./validation\noise_2_var4.wav
# Gelöscht: ./validation\noise_30_var3.wav
# Gelöscht: ./validation\noise_30_var5.wav
# Gelöscht: ./validation\noise_30_var7.wav
# Gelöscht: ./validation\noise_31_var1.wav
# Gelöscht: ./validation\noise_32_var4.wav
# Gelöscht: ./validation\noise_32_var5.wav
# Gelöscht: ./validation\noise_32_var8.wav
# Gelöscht: ./validation\noise_33_var9.wav
# Gelöscht: ./validation\noise_34_var3.wav
# Gelöscht: ./validation\noise_34_var6.wav
# Gelöscht: ./validation\noise_35_var4.wav
# Gelöscht: ./validation\noise_37_var0.wav
# Gelöscht: ./validation\noise_37_var7.wav
# Gelöscht: ./validation\noise_39_var0.wav
# Gelöscht: ./validation\noise_39_var4.wav
# Gelöscht: ./validation\noise_3_var1.wav
# Gelöscht: ./validation\noise_3_var4.wav
# Gelöscht: ./validation\noise_3_var5.wav
# Gelöscht: ./validation\noise_40_var5.wav
# Gelöscht: ./validation\noise_41_var1.wav
# Gelöscht: ./validation\noise_42_var1.wav
# Gelöscht: ./validation\noise_42_var7.wav
# Gelöscht: ./validation\noise_43_var0.wav
# Gelöscht: ./validation\noise_43_var3.wav
# Gelöscht: ./validation\noise_43_var4.wav
# Gelöscht: ./validation\noise_43_var6.wav
# Gelöscht: ./validation\noise_43_var7.wav
# Gelöscht: ./validation\noise_44_var2.wav
# Gelöscht: ./validation\noise_44_var5.wav
# Gelöscht: ./validation\noise_44_var7.wav
# Gelöscht: ./validation\noise_44_var8.wav
# Gelöscht: ./validation\noise_45_var2.wav
# Gelöscht: ./validation\noise_45_var3.wav
# Gelöscht: ./validation\noise_45_var5.wav
# Gelöscht: ./validation\noise_45_var8.wav
# Gelöscht: ./validation\noise_47_var1.wav
# Gelöscht: ./validation\noise_47_var2.wav
# Gelöscht: ./validation\noise_47_var3.wav
# Gelöscht: ./validation\noise_47_var9.wav
# Gelöscht: ./validation\noise_48_var3.wav
# Gelöscht: ./validation\noise_48_var4.wav
# Gelöscht: ./validation\noise_49_var7.wav
# Gelöscht: ./validation\noise_4_var1.wav
# Gelöscht: ./validation\noise_4_var5.wav
# Gelöscht: ./validation\noise_50_var1.wav
# Gelöscht: ./validation\noise_51_var1.wav
# Gelöscht: ./validation\noise_51_var6.wav
# Gelöscht: ./validation\noise_51_var7.wav
# Gelöscht: ./validation\noise_52_var5.wav
# Gelöscht: ./validation\noise_52_var6.wav
# Gelöscht: ./validation\noise_53_var3.wav
# Gelöscht: ./validation\noise_53_var4.wav
# Gelöscht: ./validation\noise_54_var5.wav
# Gelöscht: ./validation\noise_54_var6.wav
# Gelöscht: ./validation\noise_54_var8.wav
# Gelöscht: ./validation\noise_54_var9.wav
# Gelöscht: ./validation\noise_55_var3.wav
# Gelöscht: ./validation\noise_56_var8.wav
# Gelöscht: ./validation\noise_57_var2.wav
# Gelöscht: ./validation\noise_57_var7.wav
# Gelöscht: ./validation\noise_59_var1.wav
# Gelöscht: ./validation\noise_59_var5.wav
# Gelöscht: ./validation\noise_5_var3.wav
# Gelöscht: ./validation\noise_5_var8.wav
# Gelöscht: ./validation\noise_60_var3.wav
# Gelöscht: ./validation\noise_62_var1.wav
# Gelöscht: ./validation\noise_63_var1.wav
# Gelöscht: ./validation\noise_63_var6.wav
# Gelöscht: ./validation\noise_63_var8.wav
# Gelöscht: ./validation\noise_64_var2.wav
# Gelöscht: ./validation\noise_64_var5.wav
# Gelöscht: ./validation\noise_64_var6.wav
# Gelöscht: ./validation\noise_65_var2.wav
# Gelöscht: ./validation\noise_65_var5.wav
# Gelöscht: ./validation\noise_65_var7.wav
# Gelöscht: ./validation\noise_66_var0.wav
# Gelöscht: ./validation\noise_67_var1.wav
# Gelöscht: ./validation\noise_67_var4.wav
# Gelöscht: ./validation\noise_67_var5.wav
# Gelöscht: ./validation\noise_67_var9.wav
# Gelöscht: ./validation\noise_68_var1.wav
# Gelöscht: ./validation\noise_68_var2.wav
# Gelöscht: ./validation\noise_68_var5.wav
# Gelöscht: ./validation\noise_69_var5.wav
# Gelöscht: ./validation\noise_69_var8.wav
# Gelöscht: ./validation\noise_71_var5.wav
# Gelöscht: ./validation\noise_72_var8.wav
# Gelöscht: ./validation\noise_73_var6.wav
# Gelöscht: ./validation\noise_74_var1.wav
# Gelöscht: ./validation\noise_74_var6.wav
# Gelöscht: ./validation\noise_75_var1.wav
# Gelöscht: ./validation\noise_75_var5.wav
# Gelöscht: ./validation\noise_75_var6.wav
# Gelöscht: ./validation\noise_75_var8.wav
# Gelöscht: ./validation\noise_76_var0.wav
# Gelöscht: ./validation\noise_76_var2.wav
# Gelöscht: ./validation\noise_76_var5.wav
# Gelöscht: ./validation\noise_76_var6.wav
# Gelöscht: ./validation\noise_77_var4.wav
# Gelöscht: ./validation\noise_77_var6.wav
# Gelöscht: ./validation\noise_77_var7.wav
# Gelöscht: ./validation\noise_77_var9.wav
# Gelöscht: ./validation\noise_78_var0.wav
# Gelöscht: ./validation\noise_78_var8.wav
# Gelöscht: ./validation\noise_79_var7.wav
# Gelöscht: ./validation\noise_80_var0.wav
# Gelöscht: ./validation\noise_80_var6.wav
# Gelöscht: ./validation\noise_80_var8.wav
# Gelöscht: ./validation\noise_81_var1.wav
# Gelöscht: ./validation\noise_81_var4.wav
# Gelöscht: ./validation\noise_81_var8.wav
# Gelöscht: ./validation\noise_82_var1.wav
# Gelöscht: ./validation\noise_82_var3.wav
# Gelöscht: ./validation\noise_82_var4.wav
# Gelöscht: ./validation\noise_82_var7.wav
# Gelöscht: ./validation\noise_82_var8.wav
# Gelöscht: ./validation\noise_83_var4.wav
# Gelöscht: ./validation\noise_85_var8.wav
# Gelöscht: ./validation\noise_86_var7.wav
# Gelöscht: ./validation\noise_86_var8.wav
# Gelöscht: ./validation\noise_86_var9.wav
# Gelöscht: ./validation\noise_88_var1.wav
# Gelöscht: ./validation\noise_88_var3.wav
# Gelöscht: ./validation\noise_89_var5.wav
# Gelöscht: ./validation\noise_89_var9.wav
# Gelöscht: ./validation\noise_8_var3.wav
# Gelöscht: ./validation\noise_90_var0.wav
# Gelöscht: ./validation\noise_90_var1.wav
# Gelöscht: ./validation\noise_90_var2.wav
# Gelöscht: ./validation\noise_91_var8.wav
# Gelöscht: ./validation\noise_94_var7.wav
# Gelöscht: ./validation\noise_95_var0.wav
# Gelöscht: ./validation\noise_95_var5.wav
# Gelöscht: ./validation\noise_96_var0.wav
# Gelöscht: ./validation\noise_96_var5.wav
# Gelöscht: ./validation\noise_97_var2.wav
# Gelöscht: ./validation\noise_97_var9.wav
# Gelöscht: ./validation\noise_98_var3.wav
# Gelöscht: ./validation\noise_98_var6.wav
# Gelöscht: ./validation\noise_99_var2.wav
# Gelöscht: ./validation\noise_99_var3.wav
# Gelöscht: ./validation\noise_99_var6.wav
# Gelöscht: ./validation\noise_99_var9.wav
# Gelöscht: ./validation\noise_9_var1.wav
# Gelöscht: ./validation\noise_9_var3.wav
# Gelöscht: ./validation\noise_9_var4.wav
# Gelöscht: ./validation\noise_9_var8.wav
# Gelöscht: ./validation\noise_9_var9.wav
